# %% [markdown]
# # Part 1

# %%
# Open the file
from collections import defaultdict, deque, Counter, namedtuple
from functools import reduce, lru_cache, cmp_to_key
from heapq import heappush, heappop, heapify
from itertools import permutations, combinations, product
from math import gcd, sqrt, factorial, ceil, floor
from sortedcontainers import SortedDict, SortedList, SortedSet
import re
import sys
sys.setrecursionlimit(10000)

def scan_nums(line):
    # Use a regular expression to find numbers
    numbers = re.findall(r'-?\d+\.?\d*', line)
    # Convert to appropriate numerical types
    numbers = [float(num) if '.' in num else int(num) for num in numbers]
    return numbers

input_file = 'input.txt'
test_file = 'test.txt'

with open(test_file, 'r') as file:
    equations = []
    for line in file:
        equation = scan_nums(line)
        equations.append(equation)

            
       
                
def eval_term(equation, symbols):
    if len(equation) == 1:
        return equation[0]
    
    cur = equation[0]
    for i in range(1, len(equation)):
        if symbols[i - 1] == '+':
            cur += equation[i]
        else:
            cur *= equation[i]
    return cur
    
    
     
    
def solve(equation):
    goal, *terms = equation # unpack equation into goal and terms 
    # just try all possible combinations of addition and multiplication
    symbol_set = ['+', '*']
    combs  = product(symbol_set, repeat=len(terms) - 1)
    
    for symbols in combs:
        res  = eval_term(terms, symbols)
        if res == goal:
            return goal
    return 0

total = 0
for equation in equations:
    total += solve(equation)
print(total)
# Out:
# 3749

# %%
# Open the file
from collections import defaultdict, deque, Counter, namedtuple
from functools import reduce, lru_cache, cmp_to_key
from heapq import heappush, heappop, heapify
from itertools import permutations, combinations, product
from math import gcd, sqrt, factorial, ceil, floor
from sortedcontainers import SortedDict, SortedList, SortedSet

import sys
sys.setrecursionlimit(10000)

input_file = 'input.txt'
test_file = 'test.txt'

with open(input_file, 'r') as file:
    lines = file.readlines()
    equations = [line.strip(':').split() for line in lines]
    for eq in equations:
        
        eq[0] = int(eq[0][:-1])
        for i in range(1, len(eq)):
            eq[i] = int(eq[i])
            
def eval_term_2(equation, symbols):
    if len(equation) == 1:
        return equation[0]
    cur = equation[0]
    for i in range(1, len(equation)):
        if symbols[i - 1] == '+':
            cur += equation[i]
        elif symbols[i - 1] == '||':
            cur = int(str(cur) +  str(equation[i]))
        else:
            cur *= equation[i]
    return cur
    
    
     
    
def solve_2(equation):
    goal = equation[0]
    terms = equation[1:]
    
    cur = 0
    # just try all possible combinations of addition and multiplication
    symbol_set = ['+', '*', '||']
    combs  = product(symbol_set, repeat=len(terms) - 1)
    
    for symbols in combs:
        res  = eval_term_2(terms, symbols)
        #print(f'we got {res} with {symbols}')
        if res == goal:
            #print(f'we got {goal} with {symbols}')
            return goal
    return 0

total = 0
for equation in equations:
    total += solve_2(equation)
print(total)
# Out:
# 159490400628354
